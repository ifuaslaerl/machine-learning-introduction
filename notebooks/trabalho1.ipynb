# %% [markdown]
# Titulo do trabalho e cabeçalho

# %%
# Bibliotecas usadas
import pandas as pd
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LinearRegression, SGDClassifier, LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier

# %%
# Receber os dados

data = pd.read_csv("data/trabalho1/conjunto_de_treinamento.csv")

# %%
# Estudar as colunas não numéricas do dataframe

dados_problematicos = data.select_dtypes(exclude=[int, float, bool])

dados_problematicos.describe()
# Out:
#        forma_envio_solicitacao   sexo estado_onde_nasceu estado_onde_reside  \
# count                    20000  20000              20000              20000
# unique                       3      4                 28                 27
# top                   internet      F                 BA                 SP
# freq                     11264  12246               2351               3578
#
#        possui_telefone_residencial codigo_area_telefone_residencial  \
# count                        20000                            20000
# unique                           2                               81
# top                              Y
# freq                         16474                             3534
#
#        possui_telefone_celular vinculo_formal_com_empresa  \
# count                    20000                      20000
# unique                       1                          2
# top                          N                          N
# freq                     20000                      11174
#
#        estado_onde_trabalha possui_telefone_trabalho  \
# count                 20000                    20000
# unique                   28                        2
# top                                                N
# freq                  13573                    14519
#
#        codigo_area_telefone_trabalho
# count                          20000
# unique                            77
# top
# freq                           14525

# %%
def tratar_dados_nao_numericos(df: pd.DataFrame, coluna: str) -> pd.DataFrame:
    """ Transforma os dados em uma estrutura numérica. """

    # Verifico se os dados são binários e evito colinearidade para maior acurácia
    if len(df[coluna].unique()) == 2:
        df_coluna_tratada = pd.get_dummies(df[coluna], prefix=coluna, drop_first=True)
    else:
        df_coluna_tratada = pd.get_dummies(df[coluna], prefix=coluna)

    # axis = 1 seleciona que as operações sejam feitas nas colunas
    return pd.concat([df.drop(coluna, axis=1), df_coluna_tratada], axis=1)

# %%
# Aplicar One-Hot Encoding para todas e usar drop_first em colunas binárias para evitar colinearidade

for coluna in dados_problematicos.columns:
    data = tratar_dados_nao_numericos(data, coluna)

# %%
# Verificar se restam dados problemáticos

data.select_dtypes(exclude=[int, float, bool]).empty
# Out:
# True

# %%
# Verificar porcentagem de NaN por coluna

nan_data = data.isna().mean() * 100
nan_data = nan_data[nan_data > 0]

# Mais dados problemáticos
nan_data
# Out:
# tipo_residencia                2.680
# meses_na_residencia            7.250
# profissao                     15.485
# ocupacao                      14.890
# profissao_companheiro         57.570
# grau_instrucao_companheiro    64.300
# dtype: float64

# %%
# Analisar os dados problematicos no dataframe original
data[nan_data.index].describe()
# Out:
#        tipo_residencia  meses_na_residencia     profissao      ocupacao  \
# count     19464.000000         18550.000000  16903.000000  17022.000000
# mean          1.261303             9.572453      8.045081      2.533310
# std           0.883580            10.649580      3.210790      1.532765
# min           0.000000             0.000000      0.000000      0.000000
# 25%           1.000000             1.000000      9.000000      1.000000
# 50%           1.000000             6.000000      9.000000      2.000000
# 75%           1.000000            15.000000      9.000000      4.000000
# max           5.000000           228.000000     17.000000      5.000000
#
#        profissao_companheiro  grau_instrucao_companheiro
# count            8486.000000                 7140.000000
# mean                3.708107                    0.288095
# std                 5.181241                    0.944339
# min                 0.000000                    0.000000
# 25%                 0.000000                    0.000000
# 50%                 0.000000                    0.000000
# 75%                11.000000                    0.000000
# max                17.000000                    5.000000

# %%
data[nan_data.index].nunique()

#Para dados categóricos, preencher com nova categoria representando informação desconhecida
# Ja funciona assim com 0

#Para dados não categóricos, preencher com a média dos valores da coluna

data["meses_na_residencia"].fillna(data["meses_na_residencia"].mean(), inplace=True)
# Out:
# /tmp/ipykernel_17229/1625647055.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["meses_na_residencia"].fillna(data["meses_na_residencia"].mean(), inplace=True)

# %%
# Normalizar os dados
scaler = RobustScaler()

data_normalizada = scaler.fit_transform(data)

data = pd.DataFrame(data_normalizada, columns=data.columns, index=data.index)
data.describe()
# Out:
#        id_solicitante  produto_solicitado  dia_vencimento  tipo_endereco  \
# count    2.000000e+04        20000.000000    20000.000000   20000.000000
# mean     2.273737e-17            0.284350        0.314725       0.006350
# std      5.773936e-01            1.008239        0.674851       0.079435
# min     -1.000000e+00            0.000000       -0.900000       0.000000
# 25%     -5.000000e-01            0.000000        0.000000       0.000000
# 50%      0.000000e+00            0.000000        0.000000       0.000000
# 75%      5.000000e-01            0.000000        1.000000       0.000000
# max      1.000000e+00            6.000000        1.500000       1.000000
#
#               idade  estado_civil  qtde_dependentes  grau_instrucao  \
# count  20000.000000  20000.000000      20000.000000         20000.0
# mean       0.112024      0.120850          0.666400             0.0
# std        0.710961      1.332004          1.236725             0.0
# min       -1.571429     -2.000000          0.000000             0.0
# 25%       -0.428571     -1.000000          0.000000             0.0
# 50%        0.000000      0.000000          0.000000             0.0
# 75%        0.571429      0.000000          1.000000             0.0
# max        3.142857      5.000000         53.000000             0.0
#
#        nacionalidade  tipo_residencia  ...  codigo_area_telefone_trabalho_81  \
# count   20000.000000     19464.000000  ...                      20000.000000
# mean       -0.038400         0.261303  ...                          0.009800
# std         0.202305         0.883580  ...                          0.098511
# min        -1.000000        -1.000000  ...                          0.000000
# 25%         0.000000         0.000000  ...                          0.000000
# 50%         0.000000         0.000000  ...                          0.000000
# 75%         0.000000         0.000000  ...                          0.000000
# max         1.000000         4.000000  ...                          1.000000
#
#        codigo_area_telefone_trabalho_84  codigo_area_telefone_trabalho_85  \
# count                      20000.000000                      20000.000000
# mean                           0.006550                          0.001800
# std                            0.080669                          0.042389
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            0.000000                          0.000000
# max                            1.000000                          1.000000
#
#        codigo_area_telefone_trabalho_86  codigo_area_telefone_trabalho_9  \
# count                      20000.000000                     20000.000000
# mean                           0.004850                         0.001600
# std                            0.069475                         0.039969
# min                            0.000000                         0.000000
# 25%                            0.000000                         0.000000
# 50%                            0.000000                         0.000000
# 75%                            0.000000                         0.000000
# max                            1.000000                         1.000000
#
#        codigo_area_telefone_trabalho_90  codigo_area_telefone_trabalho_91  \
# count                      20000.000000                      20000.000000
# mean                           0.001000                          0.000850
# std                            0.031608                          0.029143
# min                            0.000000                          0.000000
# 25%                            0.000000                          0.000000
# 50%                            0.000000                          0.000000
# 75%                            0.000000                          0.000000
# max                            1.000000                          1.000000
#
#        codigo_area_telefone_trabalho_94  codigo_area_telefone_trabalho_96  \
# count                        20000.0000                      20000.000000
# mean                             0.0001                          0.000050
# std                              0.0100                          0.007071
# min                              0.0000                          0.000000
# 25%                              0.0000                          0.000000
# 50%                              0.0000                          0.000000
# 75%                              0.0000                          0.000000
# max                              1.0000                          1.000000
#
#        codigo_area_telefone_trabalho_97
# count                      20000.000000
# mean                           0.013200
# std                            0.114133
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                            1.000000
#
# [8 rows x 283 columns]

# %%
# Testar Varios parametros para o SGDClassifier

sgd_options = []
sgd_loss = ["hinge", "log_loss", "squared_hinge", "perceptron", "squared_error"]
sgd_shuffle = [True, False]
sgd_learning_rate = ["constant", "optimal", "invscaling", "adaptive"]

for loss in sgd_loss:
    for penalty in sgd_penalty:
        for intercept in sgd_intercept:
            for shuffle in sgd_shuffle:
                for learning_rate in sgd_learning_rate:
                    sgd_options.append(SGDClassifier(
                                            loss=loss, 
                                            penalty=penalty,
                                            fit_intercept=intercept,
                                            shuffle=shuffle,
                                            learning_rate=learning_rate))

# 160 tunning options
# Out:
# 320

# %%
# Funções para o KNNClassifier

def inv_ranking(distancias):
    asw = []
    for i in range(distancias):
        asw.append(1/(i+1))
    return asw

def ranking(distancias):
    asw = []
    for i in range(distancias):
        asw.append(len(distancias)-i)
    return asw

# %%
# Testar varios parâmetros para o KNNClassifier

knn_options = []

knn_n_neighbours = []
n = 2
while(n < len(data)):
    knn_n_neighbours.append(n)
    n*=2

knn_wheighs = ["uniform", "distance", ranking, inv_ranking] # Talvez adicionar mais depois
metrics = ["minkowski", "cityblock", "cosine", "euclidean", "haversine", "l1", "l2", "manhattan", "nan_euclidean"]

for n_neighbours in knn_n_neighbours:
    for wheigh in knn_wheighs:
        for metric in metrics:
            knn_options.append(KNeighborsClassifier(
                n_neighbors=n_neighbours,
                weights=wheigh,
                metric=metric
            ))

# 504 Tunning options
# Out:
# 504

# %%
# Testar LinearRegression e Logistic Regression

LinearRegression()
LogisticRegressionCV()
